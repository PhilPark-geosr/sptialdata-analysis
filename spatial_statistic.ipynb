# %%
import numpy as np
import os
from netCDF4 import Dataset
import matplotlib.pyplot as plt

# %%
from scipy import stats
a = np.array([1, 2, 3, 4, 5, 6, 7])
b = np.arange(7)
stats.pearsonr(a, b)
# Out:
# (1.0, 0.0)

# %%
flist = os.listdir('D:/ModelData/201908_C/YES3K')
flist
# Out:
# ['YES3K_2019080100.nc',
#  'YES3K_2019080200.nc',
#  'YES3K_2019080300.nc',
#  'YES3K_2019080400.nc',
#  'YES3K_2019080500.nc',
#  'YES3K_2019080600.nc',
#  'YES3K_2019080700.nc',
#  'YES3K_2019080800.nc',
#  'YES3K_2019080900.nc',
#  'YES3K_2019081000.nc',
#  'YES3K_2019081100.nc',
#  'YES3K_2019081200.nc',
#  'YES3K_2019081300.nc',
#  'YES3K_2019081400.nc',
#  'YES3K_2019081500.nc',
#  'YES3K_2019081600.nc',
#  'YES3K_2019081700.nc',
#  'YES3K_2019081800.nc',
#  'YES3K_2019081900.nc',
#  'YES3K_2019082000.nc',
#  'YES3K_2019082100.nc',
#  'YES3K_2019082200.nc',
#  'YES3K_2019082300.nc',
#  'YES3K_2019082400.nc',
#  'YES3K_2019082500.nc',
#  'YES3K_2019082600.nc',
#  'YES3K_2019082700.nc',
#  'YES3K_2019082800.nc',
#  'YES3K_2019082900.nc',
#  'YES3K_2019083000.nc',
#  'YES3K_2019083100.nc']

# %%
for fname in flist[:1]:
    print(fname)
    YES3K = Dataset('D:/ModelData/201908_C/YES3K/'+fname)

    temp = YES3K.variables['temp'][:,:,:]

    # for time in range(2):
    #     print(temp)
# Out:
# YES3K_2019080100.nc

# %%
temp0 = np.array(temp[0], dtype='float')
temp12 = np.array(temp[1], dtype='float')

# %%
plt.contourf(lon,lat,temp0)

# %%
plt.imshow(np.flipud(temp0), cmap = 'jet')

# %%
plt.figure(figsize=(30,30))
plt.imshow(np.flipud(temp12), cmap = 'jet')

# %%
from scipy import signal
from scipy import misc

# %%
corr = signal.correlate2d(temp0, temp12, boundary='symm', mode='same')

# %%
plt.imshow(corr)

# %%
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
def f(x, y):
   return np.sin(np.sqrt(x ** 2 + y ** 2))
	
x = np.linspace(-6, 6, 30)
y = np.linspace(-6, 6, 30)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, Z, 50, cmap='binary')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title('3D contour')
plt.show()

# %%
lon = YES3K.variables['lon_rho'][:]
lat = YES3K.variables['lat_rho'][:]

# %%
corr
# Out:
# array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]])

# %%
fig = plt.figure(figsize=(30,30))
ax = plt.axes(projection='3d')
ax.contour3D(lon, lat, corr, 50, cmap='binary')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title('3D contour')
plt.show()

# %%
corr
# Out:
# array([[1.59858415e+08, 1.59856978e+08, 1.59859114e+08, ...,
#         2.40153109e+08, 2.40170018e+08, 2.40186408e+08],
#        [1.59952834e+08, 1.59951964e+08, 1.59950974e+08, ...,
#         2.40161758e+08, 2.40177209e+08, 2.40195485e+08],
#        [1.60047615e+08, 1.60052882e+08, 1.60047406e+08, ...,
#         2.40167471e+08, 2.40183152e+08, 2.40200659e+08],
#        ...,
#        [1.28007005e+08, 1.27836014e+08, 1.27665640e+08, ...,
#         1.58794706e+08, 1.58586397e+08, 1.58389342e+08],
#        [1.28064856e+08, 1.27891855e+08, 1.27715582e+08, ...,
#         1.58754148e+08, 1.58552212e+08, 1.58359375e+08],
#        [1.28114821e+08, 1.27942335e+08, 1.27767519e+08, ...,
#         1.58712765e+08, 1.58513901e+08, 1.58324572e+08]])
