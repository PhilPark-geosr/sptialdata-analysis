# %%
import geoplot as gplt 
import geoplot.crs as gcrs
import geopandas as gpd
gpd.__version__
import matplotlib.pyplot as plt
import pandas as pd
import pyproj
from fiona.crs import from_epsg
import mapclassify as mc
import glob

#해안선 받아놓기

coastline= gpd.read_file('./Coastlinse_khoa/Coastlinse_khoa.shp', encoding='utf8')
#5179로변환  

coastline= coastline.to_crs(epsg=5179)

# %%
#맵 그리기 함수선언
def plot_map(data):
    ax = data.plot(figsize=(50, 30),facecolor='yellow', edgecolor='black',linewidth=0.5, zorder=2)
    coastline.plot(facecolor='#f6ebd4', edgecolor='black',ax=ax, zorder=1,linewidth=0.5)
    plt.grid(True, alpha=0.5, linestyle='--')
    
def plot_colormap(data, column, interval, data2=None, data3=None, figsize = [50,30]):
    if data2 is None:
        ax = data.plot(column, figsize=figsize,cmap = 'jet', linewidth=0, k=interval, legend=False)
        coastline.plot(facecolor='#f6ebd4', edgecolor='black',ax=ax, zorder=2,linewidth=0.5)
        plt.grid(True, alpha=0.5, linestyle='--')
    elif data3 is None:
        ax = data.plot(column, figsize=figsize,cmap = 'jet', linewidth=0, k=interval, legend=False)
        data2.plot(ax = ax, facecolor='black', edgecolor='black',linewidth=0.5)
        coastline.plot(facecolor='#f6ebd4', edgecolor='black',ax=ax, zorder=2,linewidth=0.5)
        plt.grid(True, alpha=0.5, linestyle='--')
    else:
        ax = data.plot(column, figsize=figsize,cmap = 'jet', linewidth=0, k=interval, legend=False)
        data2.plot(ax = ax, facecolor='black', edgecolor='black',linewidth=0.5)
        data3.plot(ax = ax, facecolor='red', edgecolor='black',linewidth=0.5)
        coastline.plot(facecolor='#f6ebd4', edgecolor='black',ax=ax, zorder=2,linewidth=0.5)
        plt.grid(True, alpha=0.5, linestyle='--')

# %%
input = gpd.read_file('./Ex/220203/남한육역 면적/남한육역 면적.shp', encoding='utf8')
# plot_map(input)

# %%
flist = glob.glob('./Ex/220214/기관정보/**/*.shp', recursive=True)
for fname in flist:
    print(fname.split('\\')[-1].split('.')[0])
flist
# Out:
# 수치모델 예측자료-수온
# 수치모델 예측자료-파랑
# 수치모델 예측자료-풍속
# 수치모델 예측자료-해수유동(조류)
# 퇴적물등층후
# 표층퇴적물 유형분포
# 표층퇴적물 평균입도
# 해저지형
# 개발비용(CAPEX) 5
# 개발비용(CAPEX) 5
# 개발비용(CAPEX) 8
# 개발비용(CAPEX) 8
# 예상원가(LCoE) 5
# 예상원가(LCoE) 5
# 예상원가(LCoE) 8
# 예상원가(LCoE) 8
# 터빈이용률(CF)_5
# 터빈이용률(CF)_8MW
# 입지가능해역
# 선박통항밀도
# 여객선 통항로
# 예인선 통항로
# 유조선 통항로
# 준설선 통항로
# 간선항로
# 내부지선항로
# 외부지선항로
# 한국해양대-해상교통망
# ['./Ex/220214/기관정보\\1.해양환경\\수치모델 예측자료-수온.shp',
#  './Ex/220214/기관정보\\1.해양환경\\수치모델 예측자료-파랑.shp',
#  './Ex/220214/기관정보\\1.해양환경\\수치모델 예측자료-풍속.shp',
#  './Ex/220214/기관정보\\1.해양환경\\수치모델 예측자료-해수유동(조류).shp',
#  './Ex/220214/기관정보\\1.해양환경\\퇴적물등층후.shp',
#  './Ex/220214/기관정보\\1.해양환경\\표층퇴적물 유형분포.shp',
#  './Ex/220214/기관정보\\1.해양환경\\표층퇴적물 평균입도.shp',
#  './Ex/220214/기관정보\\1.해양환경\\해저지형.shp',
#  './Ex/220214/기관정보\\2.경제성\\개발비용(CAPEX)\\개발비용(CAPEX) 5.5MW 터빈 및 석션기초.shp',
#  './Ex/220214/기관정보\\2.경제성\\개발비용(CAPEX)\\개발비용(CAPEX) 5.5MW 터빈 및 자켓기초.shp',
#  './Ex/220214/기관정보\\2.경제성\\개발비용(CAPEX)\\개발비용(CAPEX) 8.0MW 터빈 및 석션기초.shp',
#  './Ex/220214/기관정보\\2.경제성\\개발비용(CAPEX)\\개발비용(CAPEX) 8.0MW 터빈 및 자켓기초.shp',
#  './Ex/220214/기관정보\\2.경제성\\예상원가(LCoE)\\예상원가(LCoE) 5.5MW 터빈 및 석션기초.shp',
#  './Ex/220214/기관정보\\2.경제성\\예상원가(LCoE)\\예상원가(LCoE) 5.5MW 터빈 및 자켓기초.shp',
#  './Ex/220214/기관정보\\2.경제성\\예상원가(LCoE)\\예상원가(LCoE) 8.0MW 터빈 및 석션기초.shp',
#  './Ex/220214/기관정보\\2.경제성\\예상원가(LCoE)\\예상원가(LCoE) 8.0MW 터빈 및 자켓기초.shp',
#  './Ex/220214/기관정보\\2.경제성\\터빈이용률(CF)\\터빈이용률(CF)_5.5MW.shp',
#  './Ex/220214/기관정보\\2.경제성\\터빈이용률(CF)\\터빈이용률(CF)_8MW.shp',
#  './Ex/220214/기관정보\\3.해상교통\\목포해양대\\입지가능해역.shp',
#  './Ex/220214/기관정보\\3.해상교통\\선박통항\\선박통항밀도.shp',
#  './Ex/220214/기관정보\\3.해상교통\\선박통항\\여객선 통항로.shp',
#  './Ex/220214/기관정보\\3.해상교통\\선박통항\\예인선 통항로.shp',
#  './Ex/220214/기관정보\\3.해상교통\\선박통항\\유조선 통항로.shp',
#  './Ex/220214/기관정보\\3.해상교통\\선박통항\\준설선 통항로.shp',
#  './Ex/220214/기관정보\\3.해상교통\\한국해양대\\간선항로.shp',
#  './Ex/220214/기관정보\\3.해상교통\\한국해양대\\내부지선항로.shp',
#  './Ex/220214/기관정보\\3.해상교통\\한국해양대\\외부지선항로.shp',
#  './Ex/220214/기관정보\\3.해상교통\\한국해양대\\한국해양대-해상교통망.shp']

# %%
flist = ['D:/###기타업무/개인연구/2021/Geopandas/Ex/220214/기관정보/3.해상교통/한국해양대/한국해양대-해상교통망.shp']

for fname in flist[:1]:
    print(fname.split('\\')[-1].split('.')[0])
    try:
        object = gpd.read_file(fname, encoding='utf8')
        # object = object['geometry']
    except Exception as e:
        # print(e, fname)
        object = gpd.read_file(fname, encoding='euckr')
        # object = object['geometry']
    # print(object)   
    object= object.to_crs(epsg=5179)
    result = gpd.overlay( input, object, how='difference')
    try:
        result = gpd.overlay(object, input,how='difference')
    
    # columnlist = result.columns.tolist()
    # result=result[[columnlist[0], 'geometry']]
        # result=result[['geometry']]

    # print('저장을 시작합니다')
        # result.to_file('./result/ex10/shp/'+fname.split('\\')[-1].split('.')[0]+'.shp', encoding='euckr')
    except Exception as e:
        print(e)
        pass
    # print('저장이 완료되었습니다' )
    # plot_map(result)
    # result = gpd.sjoin(object, input,  op='intersects')
    # plt.savefig('./result
    # /ex8/'+fname.split('\\')[-1].split('.')[0],dpi=300)
    # plt.savefig('./result/ex8/test.png')
    # result.drop_duplicates(['MIN1'], keep='first', inplace=True)
# Out:
# D:/###기타업무/개인연구/2021/Geopandas/Ex/220214/기관정보/3

# %%
result
# Out:
#         항로  begin   end                                           geometry
# 0   지선항로39    NaN   NaN                                               None
# 1    광역항로1    1.0  36.0  POLYGON ((874650.830 1894115.307, 868236.230 1...
# 2    광역항로2    1.0  39.0  POLYGON ((825651.113 1572955.156, 824643.573 1...
# 3    지선항로1    1.0  15.0  MULTIPOLYGON (((863038.445 1865424.081, 861470...
# 4    지선항로2    1.0  16.0  POLYGON ((913730.066 1905307.116, 912973.093 1...
# 5    지선항로3    1.0   7.0  POLYGON ((897162.216 1896246.538, 897154.717 1...
# 6    지선항로4    1.0   4.0  POLYGON ((880324.795 1875909.159, 880408.704 1...
# 7    지선항로5    1.0   4.0  POLYGON ((868088.884 1890084.520, 859671.184 1...
# 8    지선항로6    1.0   4.0  POLYGON ((856526.300 1850845.985, 851133.931 1...
# 9    지선항로7    1.0   6.0  POLYGON ((897063.570 1775439.230, 897046.261 1...
# 10   지선항로8    1.0   8.0  POLYGON ((845843.945 1735934.154, 846130.169 1...
# 11   지선항로9    1.0   4.0  POLYGON ((803380.398 1693579.027, 806515.316 1...
# 12  지선항로10    1.0  40.0  POLYGON ((833862.865 1653455.692, 835428.380 1...
# 13  지선항로11    1.0   4.0  POLYGON ((785813.986 1649027.339, 787462.032 1...
# 14  지선항로12    1.0   5.0  POLYGON ((779913.016 1634060.092, 780592.659 1...
# 15  지선항로13    1.0   6.0  POLYGON ((866279.997 1604703.187, 868372.091 1...
# 16  지선항로14    1.0   5.0  POLYGON ((879776.694 1586156.823, 880842.642 1...
# 17  지선항로15    1.0   4.0  POLYGON ((879853.440 1562094.622, 882954.100 1...
# 18  지선항로16    1.0   4.0  POLYGON ((880705.107 1531862.326, 883365.976 1...
# 19  지선항로17    1.0   4.0  POLYGON ((882321.313 1495738.714, 884011.428 1...
# 20  지선항로18    1.0   6.0  POLYGON ((874298.664 1589679.403, 878875.435 1...
# 21  지선항로19    1.0   4.0  POLYGON ((897921.200 1561050.323, 902278.215 1...
# 22  지선항로20    1.0   4.0  POLYGON ((907717.254 1529283.450, 911350.327 1...
# 23  지선항로21    1.0   5.0  POLYGON ((910125.192 1511672.409, 911939.338 1...
# 24  지선항로22    1.0   4.0  POLYGON ((860043.729 1492831.827, 930152.426 1...
# 25  지선항로23    1.0   4.0  POLYGON ((935465.790 1583790.328, 937180.603 1...
# 26  지선항로24    1.0   4.0  POLYGON ((917356.504 1560675.507, 930545.756 1...
# 27  지선항로25    1.0   4.0  POLYGON ((912428.548 1560227.033, 917356.504 1...
# 28  지선항로26    1.0   4.0  POLYGON ((946619.768 1543216.421, 961477.438 1...
# 29  지선항로27    1.0   4.0  POLYGON ((945968.892 1500624.406, 952157.966 1...
# 30  지선항로28    1.0   4.0  POLYGON ((964438.463 1554405.777, 966372.868 1...
# 31  지선항로29    1.0   4.0  POLYGON ((988095.140 1554562.077, 983683.030 1...
# 32  지선항로30    1.0   4.0  POLYGON ((1018550.159 1554511.165, 1005543.160...
# 33  지선항로31    1.0   4.0  POLYGON ((1038768.546 1622366.991, 1042844.114...
# 34  지선항로32    1.0   4.0  POLYGON ((1045553.078 1615405.521, 1043927.250...
# 35  지선항로33    1.0   4.0  POLYGON ((1042640.570 1560687.513, 1028936.368...
# 36  지선항로34    1.0   4.0  POLYGON ((971885.121 1468331.538, 966131.242 1...
# 37  지선항로35    1.0  14.0  POLYGON ((1042793.027 1622415.531, 1060817.393...
# 38  지선항로36    1.0   4.0  POLYGON ((1120665.107 1665623.374, 1138291.850...
# 39  지선항로37    1.0   9.0  POLYGON ((1138291.850 1670649.968, 1138923.104...
# 40  지선항로38    1.0   6.0  POLYGON ((1174173.953 1713616.172, 1174728.957...
# 41  지선항로39    1.0   8.0  POLYGON ((1177999.358 1788013.927, 1177972.426...
# 42   지선항로1    NaN   NaN                                               None
# 43   지선항로2    NaN   NaN                                               None
# 44  지선항로38    NaN   NaN                                               None

# %%
plot_colormap(result, 'end', 10)

# %%
object
# Out:
#         항로  begin   end                                           geometry
# 0   지선항로39    NaN   NaN                                               None
# 1    광역항로1    1.0  36.0  POLYGON ((874650.830 1894115.307, 868236.230 1...
# 2    광역항로2    1.0  39.0  POLYGON ((861470.861 1866269.510, 866535.707 1...
# 3    지선항로1    1.0  15.0  POLYGON ((881370.358 1908043.179, 882520.552 1...
# 4    지선항로2    1.0  16.0  POLYGON ((913730.066 1905307.116, 912973.093 1...
# 5    지선항로3    1.0   7.0  POLYGON ((897162.216 1896246.538, 897154.717 1...
# 6    지선항로4    1.0   4.0  POLYGON ((880324.795 1875909.159, 880408.704 1...
# 7    지선항로5    1.0   4.0  POLYGON ((868088.884 1890084.520, 859671.184 1...
# 8    지선항로6    1.0   4.0  POLYGON ((856526.300 1850845.985, 851133.931 1...
# 9    지선항로7    1.0   6.0  POLYGON ((897063.570 1775439.230, 897046.261 1...
# 10   지선항로8    1.0   8.0  POLYGON ((845843.945 1735934.154, 846130.169 1...
# 11   지선항로9    1.0   4.0  POLYGON ((803380.398 1693579.027, 806515.316 1...
# 12  지선항로10    1.0  40.0  POLYGON ((833862.865 1653455.692, 835428.380 1...
# 13  지선항로11    1.0   4.0  POLYGON ((785813.986 1649027.339, 787462.032 1...
# 14  지선항로12    1.0   5.0  POLYGON ((779913.016 1634060.092, 780592.659 1...
# 15  지선항로13    1.0   6.0  POLYGON ((866279.997 1604703.187, 868372.091 1...
# 16  지선항로14    1.0   5.0  POLYGON ((879776.694 1586156.823, 880842.642 1...
# 17  지선항로15    1.0   4.0  POLYGON ((879853.440 1562094.622, 882954.100 1...
# 18  지선항로16    1.0   4.0  POLYGON ((880705.107 1531862.326, 883365.976 1...
# 19  지선항로17    1.0   4.0  POLYGON ((882321.313 1495738.714, 884011.428 1...
# 20  지선항로18    1.0   6.0  POLYGON ((874298.664 1589679.403, 878875.435 1...
# 21  지선항로19    1.0   4.0  POLYGON ((897921.200 1561050.323, 902278.215 1...
# 22  지선항로20    1.0   4.0  POLYGON ((907717.254 1529283.450, 911350.327 1...
# 23  지선항로21    1.0   5.0  POLYGON ((910125.192 1511672.409, 911939.338 1...
# 24  지선항로22    1.0   4.0  POLYGON ((860043.729 1492831.827, 930152.426 1...
# 25  지선항로23    1.0   4.0  POLYGON ((935465.790 1583790.328, 937180.603 1...
# 26  지선항로24    1.0   4.0  POLYGON ((917356.504 1560675.507, 930545.756 1...
# 27  지선항로25    1.0   4.0  POLYGON ((912428.548 1560227.033, 917356.504 1...
# 28  지선항로26    1.0   4.0  POLYGON ((946619.768 1543216.421, 961477.438 1...
# 29  지선항로27    1.0   4.0  POLYGON ((945968.892 1500624.406, 952157.966 1...
# 30  지선항로28    1.0   4.0  POLYGON ((964438.463 1554405.777, 966372.868 1...
# 31  지선항로29    1.0   4.0  POLYGON ((988095.140 1554562.077, 983683.030 1...
# 32  지선항로30    1.0   4.0  POLYGON ((1018550.159 1554511.165, 1005543.160...
# 33  지선항로31    1.0   4.0  POLYGON ((1038768.546 1622366.991, 1042844.114...
# 34  지선항로32    1.0   4.0  POLYGON ((1045553.078 1615405.521, 1043927.250...
# 35  지선항로33    1.0   4.0  POLYGON ((1042640.570 1560687.513, 1028936.368...
# 36  지선항로34    1.0   4.0  POLYGON ((971885.121 1468331.538, 966131.242 1...
# 37  지선항로35    1.0  14.0  POLYGON ((1042793.027 1622415.531, 1060817.393...
# 38  지선항로36    1.0   4.0  POLYGON ((1120665.107 1665623.374, 1138291.850...
# 39  지선항로37    1.0   9.0  POLYGON ((1138291.850 1670649.968, 1138923.104...
# 40  지선항로38    1.0   6.0  POLYGON ((1174173.953 1713616.172, 1174728.957...
# 41  지선항로39    1.0   8.0  POLYGON ((1177999.358 1788013.927, 1177972.426...
# 42   지선항로1    NaN   NaN                                               None
# 43   지선항로2    NaN   NaN                                               None
# 44  지선항로38    NaN   NaN                                               None

# %%
plot_map(object)

# %%
df = object.difference(input)
plot_map(df)
# Out:
# C:\Users\PPARK\anaconda3\envs\geopandas2\lib\site-packages\geopandas\base.py:32: UserWarning: The indices of the two GeoSeries are different.
#   warn("The indices of the two GeoSeries are different.")

# %%
df.dropna(inplace=True)
df
# Out:
# 0     MULTIPOLYGON (((857737.134 1584166.650, 857659...
# 1     POLYGON ((1171527.592 1722643.140, 1171515.787...
# 2     POLYGON ((1170531.460 1724226.187, 1170517.834...
# 3     POLYGON ((886716.028 1881865.070, 886551.331 1...
# 4     POLYGON ((938707.045 1884761.289, 938531.511 1...
# 5     POLYGON ((933877.575 1888937.644, 931366.270 1...
# 6     POLYGON ((898677.945 1893901.229, 898217.141 1...
# 7     POLYGON ((917012.540 1899749.139, 916821.039 1...
# 8     POLYGON ((902387.034 1893296.682, 900868.054 1...
# 9     POLYGON ((925163.442 1896889.405, 921859.087 1...
# 10    POLYGON ((916560.703 1928973.309, 916214.764 1...
# 11    POLYGON ((914624.888 1934022.779, 914344.784 1...
# 12    POLYGON ((919461.313 1943461.326, 919422.228 1...
# 13    POLYGON ((910503.484 1503842.188, 910462.726 1...
# 14    POLYGON ((910285.857 1897893.850, 907803.600 1...
# 15    POLYGON ((904677.563 1908275.525, 904359.647 1...
# 16    POLYGON ((930630.107 1890235.111, 930416.555 1...
# 17    POLYGON ((912342.261 1905909.908, 907605.810 1...
# 18    POLYGON ((920497.999 1946018.863, 920080.644 1...
# 19    POLYGON ((908801.811 1926317.295, 909142.656 1...
# 20    POLYGON ((912391.641 1472373.305, 912352.370 1...
# 21    POLYGON ((910549.959 1504645.252, 908381.914 1...
# 22    POLYGON ((895414.446 1639756.506, 895413.112 1...
# 23    POLYGON ((897152.962 1641344.314, 897111.012 1...
# 24    POLYGON ((881401.014 1892661.881, 879229.947 1...
# 25    POLYGON ((902058.788 1922170.848, 902003.582 1...
# 26    POLYGON ((919522.248 1934723.076, 918157.382 1...
# 27    POLYGON ((830903.413 1965981.735, 826046.851 1...
# 28    POLYGON ((909926.837 1503395.089, 909874.154 1...
# 29    POLYGON ((1171530.788 1722444.129, 1171518.868...
# 30    POLYGON ((902315.637 1893319.081, 903344.842 1...
# 31    POLYGON ((1171464.659 1723024.954, 1171471.246...
# 32    POLYGON ((1168158.164 1725150.573, 1168049.964...
# 33    POLYGON ((939207.335 1883920.667, 939005.587 1...
# 34    POLYGON ((938536.039 1885656.054, 938368.708 1...
# 35    POLYGON ((891484.249 1889573.692, 890583.374 1...
# 36    POLYGON ((1167791.545 1720597.871, 1167774.743...
# 37    POLYGON ((1171534.205 1722109.489, 1171520.125...
# 38    POLYGON ((918360.403 1937344.897, 919082.535 1...
# 39    POLYGON ((914158.554 1471522.931, 914039.114 1...
# 40    POLYGON ((912582.381 1472249.304, 912572.730 1...
# 41    POLYGON ((912532.344 1472398.520, 912591.081 1...
# 42    POLYGON ((895457.183 1639716.877, 895459.496 1...
# 43    POLYGON ((895361.459 1639825.314, 895355.144 1...
# 44    POLYGON ((895349.961 1639835.507, 895345.266 1...
# 45    POLYGON ((1168148.117 1718610.246, 1168148.200...
# 46    POLYGON ((1167275.936 1720865.788, 1167269.977...
# dtype: geometry

# %%
input
# Out:
#        OBJECTID   Shape_Leng    Shape_Area  label  _count  _sum  _mean  \
# 0           539   290.177191   4651.114803  lnd_a     0.0   0.0    NaN
# 1           540   107.030900    453.482427  lnd_a     0.0   0.0    NaN
# 2           541   251.099622   2172.038062  lnd_a     0.0   0.0    NaN
# 3           542   150.209545   1521.482416  lnd_a     0.0   0.0    NaN
# 4           543   355.363105   6384.658359  lnd_a     0.0   0.0    NaN
# ...         ...          ...           ...    ...     ...   ...    ...
# 19097     19990   215.102510   2932.528162  lnd_a     0.0   0.0    NaN
# 19098     19991    65.791039    299.247679  lnd_a     0.0   0.0    NaN
# 19099     19992     5.031071      1.933996  lnd_a     0.0   0.0    NaN
# 19100     19993     4.570763      1.511995  lnd_a     0.0   0.0    NaN
# 19101     19994  1165.444003  41614.239695  lnd_a     0.0   0.0    NaN
#
#            area                                           geometry
# 0      0.004648  POLYGON ((890129.044 1542331.732, 890131.095 1...
# 1      0.000453  POLYGON ((890110.041 1542384.587, 890112.362 1...
# 2      0.002171  POLYGON ((893121.627 1545874.175, 893121.707 1...
# 3      0.001520  POLYGON ((893169.924 1546042.298, 893171.130 1...
# 4      0.006380  POLYGON ((893105.356 1546162.714, 893105.576 1...
# ...         ...                                                ...
# 19097  0.002930  POLYGON ((888660.365 1520584.079, 888660.606 1...
# 19098  0.000299  POLYGON ((894311.462 1526853.077, 894311.542 1...
# 19099  0.000002  POLYGON ((894314.388 1526888.322, 894314.549 1...
# 19100  0.000002  POLYGON ((894047.655 1526988.930, 894048.319 1...
# 19101  0.041586  POLYGON ((894103.191 1527056.005, 894103.572 1...
#
# [19102 rows x 9 columns]

# %% [markdown]
# result
